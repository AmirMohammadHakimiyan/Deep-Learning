# %%
! pip install onnxruntime
# Out:
# Collecting onnxruntime
#   Downloading onnxruntime-1.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 16.3 MB/s eta 0:00:00
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (23.5.26)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (23.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (1.12)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime) (1.3.0)
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-1.16.3

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from insightface.app import FaceAnalysis

# %%
model =FaceAnalysis(name="buffalo_l" , providers=['CPUExecutionProvider'])
model.prepare(ctx_id=0, det_size=(640, 640))
# Out:
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (640, 640)

# %%
face_bank_path= "drive/MyDrive/FaceBank/"
face_bank=[]
for person_name in os.listdir(face_bank_path):
    file_path = os.path.join(face_bank_path, person_name)
    if os.path.isdir(file_path):
        for img_name in os.listdir(file_path):
            img_path = os.path.join(file_path, img_name)
            img = cv2.imread(img_path,)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            result = model.get(img)
            if len(result) > 1:
                print(person_name,img_name)
                print("!!warning: more than one face detected in image!!")
                continue
            if not result:
                print(person_name,img_name)
                print("!!warning: no face detected in image!!")
                continue
            print("❤")
            embedding = result[0]["embedding"]
            my_dict = {"name": person_name, "embedding": embedding}
            face_bank.append(my_dict)
np.save("output/face_bank.npy", face_bank)
# Out:
# /usr/local/lib/python3.10/dist-packages/insightface/utils/transform.py:68: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   P = np.linalg.lstsq(X_homo, Y)[0].T # Affine matrix. 3 x 4
# ❤
# Hamid_Lolaei 456456455-2.jpg
# !!warning: no face detected in image!!
# Hamid_Lolaei 10041-2.jpg
# !!warning: no face detected in image!!
# Hamid_Lolaei 1032835_591-0.jpg
# !!warning: no face detected in image!!
# ❤
# ❤
# ❤
# ❤
# Hamid_Lolaei 159721_898-1.jpg
# !!warning: no face detected in image!!
# ❤
# ❤
# ❤
# ❤
# Hamid_Lolaei 219979_396-1.jpg
# !!warning: no face detected in image!!
# ❤
# ❤
# Hamid_Lolaei 272-0.jpg
# !!warning: no face detected in image!!
# ❤
# ❤
# ❤
# Hamid_Lolaei 35164766-3420-b__4313-0.jpg
# !!warning: no face detected in image!!
# ❤
# ❤
# Hamid_Lolaei maxresdefault (6)-0.jpg
# !!warning: no face detected in image!!
# Hamid_Lolaei maxresdefault (7)-0.jpg
# !!warning: no face detected in image!!
# Hamid_Lolaei maxresdefault (7)-1.jpg
# !!warning: no face detected in image!!
# Hamid_Lolaei maxresdefault (7)-4.jpg
# !!warning: no face detected in image!!
# ❤
# Hamid_Lolaei photo-hamid-lolaei-2-2.jpg
# !!warning: no face detected in image!!
# ❤
# Hamid_Lolaei ske851-1.jpg
# !!warning: no face detected in image!!
# Hamid_Lolaei بیوگرافی-کامل-حمید-لولایی-عکس-11-600x436-0.jpg
# !!warning: no face detected in image!!
# ❤
# Hamid_Lolaei حمید+لولایی-0.jpg
# !!warning: no face detected in image!!
# ❤
# ❤
# Hamid_Lolaei 4603826-0.jpg
# !!warning: no face detected in image!!
# ❤
# Hamid_Lolaei 560546_111-1.jpg
# !!warning: no face detected in image!!
# Hamid_Lolaei 62153936-0.jpg
# !!warning: no face detected in image!!
# ❤
# Hamid_Lolaei 6283921-2603-b__9234-0.jpg
# !!warning: no face detected in image!!
# Hamid_Lolaei 88107-0.jpg
# !!warning: more than one face detected in image!!
# Hamid_Lolaei 88107-2.jpg
# !!warning: no face detected in image!!
# ❤
# ❤
# ❤
01.jpg
# !!warning: no face detected in image!!
# ❤
# ❤
# ❤
# ❤
# Leyla_Hatami Leyla-Hatami-38_01.jpg
# !!warning: no face detected in image!!
# Leyla_Hatami Leyla-Hatami-16_01.jpg
# !!warning: no face detected in image!!
# Leyla_Hatami Leyla-Hatami-59_01.jpg
# !!warning: no face detected in image!!
# Leyla_Hatami Leyla-Hatami-99_01.jpg
# !!warning: no face detected in image!!
# Leyla_Hatami Leyla-Hatami-68_01.jpg
# !!warning: no face detected in image!!
# Leyla_Hatami Leyla-Hatami-96_01.jpg
# !!warning: no face detected in image!!
# ❤
# ❤
# ❤
# ❤
# ❤
# ❤
# Leyla_Hatami Leyla-Hatami-65_01.jpg
# !!warning: no face detected in image!!
# Leyla_Hatami Leyla-Hatami-93_01.jpg
# !!warning: no face detected in image!!
# ❤
# ❤
# Ebi file2Fmedia2Fimage2Foriginal2F2223-2-0.jpg
# !!warning: no face detected in image!!
# Ebi 10531426955541454494-2.jpg
# !!warning: no face detected in image!!
# Ebi 10531434510312313782-0.jpg
# !!warning: no face detected in image!!
# Ebi 146196-0.jpg
# !!warning: no face detected in image!!
# ❤
# Ebi 19870219-5936-b__3525-0.jpg
# !!warning: no face detected in image!!
# Ebi 1870741829-talab-org-1.jpg
# !!warning: no face detected in image!!
# Ebi 3168-0.jpg
# !!warning: no face detected in image!!
# Ebi 320746856-parsnaz-com-0.jpg
# !!warning: no face detected in image!!
# Ebi 7p1iv1-0.jpg
# !!warning: no face detected in image!!
# ❤
# Ebi 823182830-talab-org-0.jpg
# !!warning: no face detected in image!!
# Ebi 9008813-8244-b__5555-0.jpg
# !!warning: no face detected in image!!
# Ebi ac-image-eJ1577868287Pu-0.jpg
# !!warning: no face detected in image!!
# Ebi ac-image-jf157786860742-0.jpg
# !!warning: no face detected in image!!
# Ebi ac-image-ot15778687413s-0.jpg
# !!warning: no face detected in image!!
# Ebi Bu3J9avCYAA1juE-0.jpg
# !!warning: no face detected in image!!
# Ebi DVNApWLWsAAjIu3-1.jpg
# !!warning: no face detected in image!!
# Ebi Ebi-Nazy-Naz-Kon-Pichak-Live-0.jpg
# !!warning: no face detected in image!!
# Ebi ebihamedi-photokade-com-1-1-0.jpg
# !!warning: no face detected in image!!
# ❤
# Ebi maxresdefault (1)-0.jpg
# !!warning: no face detected in image!!
# Ebi _112295165_photo-2020-05-15-17-04-36-4.jpg
# !!warning: no face detected in image!!
# Ebi آهنگ-جدید-ابی-در-مورد-شهدا-و-اسپانسر-قمار-باز-0.jpg
# !!warning: no face detected in image!!
# Ebi ابراهیم-حامدی-8-0.jpg
# !!warning: no face detected in image!!
# Ebi ابی-ebi-0.jpg
# !!warning: no face detected in image!!
# Ebi ابی-0.jpg
# !!warning: no face detected in image!!
# ❤
# Ebi 160203_626-2.jpg
# !!warning: no face detected in image!!
# Ebi feRyIW7-3.jpg
# !!warning: no face detected in image!!
# Ebi mahnaz_afshar-ebi-0.jpg
# !!warning: no face detected in image!!
# Ebi 66302834292949459342_0-3.jpg
# !!warning: no face detected in image!!
# Ebi Biography-of-Siavash-Ghomayshi-2-1.jpg
# !!warning: no face detected in image!!
